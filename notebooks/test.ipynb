# %% [markdown]
# ## **Import Required Libraries**

# %%
import os
import time
import sys
from pathlib import Path
from dotenv import load_dotenv

## Define project root
_PROJECT_ROOT=Path.cwd().parent
sys.path.insert(0,str(_PROJECT_ROOT))

## Load enviromental variables
load_dotenv(_PROJECT_ROOT/".env")

##====================================
## Import User Define Python Modules
##====================================
from src.infrastructure.config import (
    validate,
    dump
)
from src.agents.intent_router import RouterIntent
from src.agents.sql_generator import SQLGenerator
from src.infrastructure.llm.llm_providers import _global_llm_provider,_llm_service_provider
from src.agents.orchestrator import Orchestrator
from scripts.test_supabase import main

# %%
# Validate and display config
try:
    validate()
    main()
    dump()
except Exception as e:
    print(f"⚠️  Config note: {e}")

print(f"✅ Enviromental Loaded.")
print(f"📁 Project root: {_PROJECT_ROOT}")
# Out:
# 2026-04-23 20:35:32.363 | INFO     | src.infrastructure.config:validate:410 - All required environment variables are set
# 2026-04-23 20:35:32.364 | INFO     | scripts.test_supabase:main:17 - Testing database connection…
# 2026-04-23 20:35:32.464 | INFO     | src.infrastructure.db.sql_client:_supabase_sql_engine:48 - ✓ Supabase SQL engine created
# 2026-04-23 20:35:41.085 | INFO     | src.infrastructure.db.supabase_client:_test_connection:75 - ✅ Supabase connection test: SUCCESS
# 2026-04-23 20:35:41.085 | SUCCESS  | scripts.test_supabase:main:21 - All checks passed! Supabase is ready.
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
# 🌐 Provider:
#    Provider: openrouter
#    Model Tier: general
#    Openrouter Base URL: https://openrouter.ai/api/v1
#    Chat Model: openai/gpt-4o-mini
# ============================================================
#
# ✅ Enviromental Loaded.
# 📁 Project root: c:\UOC pdf\AI Engineering Bootcamp\mini-project-04

# %%
llm=_llm_service_provider()
orchestrator=Orchestrator(llm=llm)

basic_user_query=[
"List all patients",
#"Show all doctors",
#"List all departments",
#"Show all staff members",
]

for query in basic_user_query:
    result=orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:35:56.510 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:35:58.787 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:35:58.787 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:35:58.788 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:35:59.681 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:35:59.682 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:35:59.683 | INFO     | src.agents.orchestrator:agent_orchestrator:272 - SQL generator agent is called
# 2026-04-23 20:36:00.445 | INFO     | src.agents.orchestrator:agent_orchestrator:283 - SQL generator agent is completed
# 2026-04-23 20:36:00.447 | INFO     | src.agents.orchestrator:agent_orchestrator:286 - Generated SQL query: SELECT * FROM patients;
# 2026-04-23 20:36:00.447 | INFO     | src.agents.orchestrator:agent_orchestrator:288 - User query: List all patients
# 2026-04-23 20:36:00.448 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:36:00.448 | INFO     | src.infrastructure.guardrails.guardrails:_is_select:171 - SQL query is safe. Proceeding to syntax checking
# 2026-04-23 20:36:01.139 | DEBUG    | src.infrastructure.guardrails.guardrails:_is_query_syntax_valid:221 - LLM syntax response
# 2026-04-23 20:36:01.140 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:276 - SQL query syntax varified.Processing for database execution
# 2026-04-23 20:36:01.141 | INFO     | src.agents.orchestrator:agent_orchestrator:294 - SQL query is safe and valid
# 2026-04-23 20:36:01.141 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:110 - Executing SQL query on Supabase database
# 2026-04-23 20:36:14.876 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:128 - ✅ Query executed successfully: 50000 rows returned
# 2026-04-23 20:36:14.877 | INFO     | src.agents.orchestrator:agent_orchestrator:303 - Latency: 18367ms
# 2026-04-23 20:36:14.877 | INFO     | src.agents.orchestrator:agent_orchestrator:304 - Total Tokens: 467
# 2026-04-23 20:36:14.877 | INFO     | src.agents.orchestrator:agent_orchestrator:305 - Total Token Cost: $0.000077
# ====================================================================================================

# %%
intermidiate_user_query=[
#"Show patients older than 60",
"List doctors with specialty cardiology",
#"Show appointments scheduled today",
#"List admissions in the last 7 days",
]

for query in intermidiate_user_query:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:36:46.647 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:36:48.035 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:36:48.037 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:36:48.037 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:36:49.107 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:36:49.108 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:36:49.109 | INFO     | src.agents.orchestrator:agent_orchestrator:272 - SQL generator agent is called
# 2026-04-23 20:36:51.111 | INFO     | src.agents.orchestrator:agent_orchestrator:283 - SQL generator agent is completed
# 2026-04-23 20:36:51.111 | INFO     | src.agents.orchestrator:agent_orchestrator:286 - Generated SQL query: SELECT d.doctor_id, d.first_name, d.last_name, s.specialty_name
# FROM doctors d
# JOIN specialties s ON d.specialty_id = s.specialty_id
# WHERE LOWER(s.specialty_name) = 'cardiology';
# 2026-04-23 20:36:51.113 | INFO     | src.agents.orchestrator:agent_orchestrator:288 - User query: List doctors with specialty cardiology
# 2026-04-23 20:36:51.113 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:36:51.113 | INFO     | src.infrastructure.guardrails.guardrails:_is_select:171 - SQL query is safe. Proceeding to syntax checking
# 2026-04-23 20:36:51.797 | DEBUG    | src.infrastructure.guardrails.guardrails:_is_query_syntax_valid:221 - LLM syntax response
# 2026-04-23 20:36:51.799 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:276 - SQL query syntax varified.Processing for database execution
# 2026-04-23 20:36:51.800 | INFO     | src.agents.orchestrator:agent_orchestrator:294 - SQL query is safe and valid
# 2026-04-23 20:36:51.800 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:110 - Executing SQL query on Supabase database
# 2026-04-23 20:36:52.476 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:128 - ✅ Query executed successfully: 16 rows returned
# 2026-04-23 20:36:52.478 | INFO     | src.agents.orchestrator:agent_orchestrator:303 - Latency: 5831ms
# 2026-04-23 20:36:52.479 | INFO     | src.agents.orchestrator:agent_orchestrator:304 - Total Tokens: 534
# 2026-04-23 20:36:52.479 | INFO     | src.agents.orchestrator:agent_orchestrator:305 - Total Token Cost: $0.000106
# ====================================================================================================

# %%
aggregation_queries=[
#"Total revenue generated",
#"Count of patients",
"Average patient age",
#"Total number of appointments",
]

for query in aggregation_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:37:58.118 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:38:00.061 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:38:00.063 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:38:00.064 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:38:01.209 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:38:01.210 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:38:01.210 | INFO     | src.agents.orchestrator:agent_orchestrator:272 - SQL generator agent is called
# 2026-04-23 20:38:02.907 | INFO     | src.agents.orchestrator:agent_orchestrator:283 - SQL generator agent is completed
# 2026-04-23 20:38:02.907 | INFO     | src.agents.orchestrator:agent_orchestrator:286 - Generated SQL query: SELECT AVG(EXTRACT(YEAR FROM AGE(date_of_birth))) AS average_age FROM patients;
# 2026-04-23 20:38:02.907 | INFO     | src.agents.orchestrator:agent_orchestrator:288 - User query: Average patient age
# 2026-04-23 20:38:02.910 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:38:02.910 | INFO     | src.infrastructure.guardrails.guardrails:_is_select:171 - SQL query is safe. Proceeding to syntax checking
# 2026-04-23 20:38:03.832 | DEBUG    | src.infrastructure.guardrails.guardrails:_is_query_syntax_valid:221 - LLM syntax response
# 2026-04-23 20:38:03.833 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:276 - SQL query syntax varified.Processing for database execution
# 2026-04-23 20:38:03.834 | INFO     | src.agents.orchestrator:agent_orchestrator:294 - SQL query is safe and valid
# 2026-04-23 20:38:03.834 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:110 - Executing SQL query on Supabase database
# 2026-04-23 20:38:04.446 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:128 - ✅ Query executed successfully: 1 rows returned
# 2026-04-23 20:38:04.447 | INFO     | src.agents.orchestrator:agent_orchestrator:303 - Latency: 6328ms
# 2026-04-23 20:38:04.447 | INFO     | src.agents.orchestrator:agent_orchestrator:304 - Total Tokens: 480
# 2026-04-23 20:38:04.448 | INFO     | src.agents.orchestrator:agent_orchestrator:305 - Total Token Cost: $0.000085
# ====================================================================================================

# %%
group_by_queries=[
"Total revenue by department",
##"Number of patients per department",
##"Count of appointments per doctor",
##"Total payments by month",
]

for query in group_by_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:38:27.051 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:38:28.362 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:38:28.363 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:38:28.364 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:38:31.121 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:38:31.121 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:38:31.122 | INFO     | src.agents.orchestrator:agent_orchestrator:272 - SQL generator agent is called
# 2026-04-23 20:38:31.123 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-23 20:38:31.123 | WARNING  | src.agents.orchestrator:agent_orchestrator:276 - SQL query is not generated.Please check you prompt or schema
# ====================================================================================================

# %%
join_queries=[
##"List patients with their doctors",
"Show appointments with patient and doctor names",
##"List billing invoices with department names",
##"Show payments with invoice details",
]

for query in join_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:38:52.159 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:38:53.247 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:38:53.248 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:38:53.248 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:38:54.157 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:38:54.158 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:38:54.159 | INFO     | src.agents.orchestrator:agent_orchestrator:272 - SQL generator agent is called
# 2026-04-23 20:38:56.768 | INFO     | src.agents.orchestrator:agent_orchestrator:283 - SQL generator agent is completed
# 2026-04-23 20:38:56.769 | INFO     | src.agents.orchestrator:agent_orchestrator:286 - Generated SQL query: SELECT
#     a.appointment_id,
#     CONCAT(p.first_name, ' ', p.last_name) AS patient_name,
#     CONCAT(d.first_name, ' ', d.last_name) AS doctor_name,
#     a.appointment_date,
#     a.appointment_time,
#     a.reason,
#     a.status
# FROM
#     appointments a
# JOIN
#     patients p ON a.patient_id = p.patient_id
# JOIN
#     doctors d ON a.doctor_id = d.doctor_id;
# 2026-04-23 20:38:56.770 | INFO     | src.agents.orchestrator:agent_orchestrator:288 - User query: Show appointments with patient and doctor names
# 2026-04-23 20:38:56.770 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:38:56.772 | INFO     | src.infrastructure.guardrails.guardrails:_is_select:171 - SQL query is safe. Proceeding to syntax checking
# 2026-04-23 20:38:59.068 | DEBUG    | src.infrastructure.guardrails.guardrails:_is_query_syntax_valid:221 - LLM syntax response
# 2026-04-23 20:38:59.069 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:276 - SQL query syntax varified.Processing for database execution
# 2026-04-23 20:38:59.070 | INFO     | src.agents.orchestrator:agent_orchestrator:294 - SQL query is safe and valid
# 2026-04-23 20:38:59.071 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:110 - Executing SQL query on Supabase database
# 2026-04-23 20:39:10.495 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:128 - ✅ Query executed successfully: 200000 rows returned
# 2026-04-23 20:39:10.496 | INFO     | src.agents.orchestrator:agent_orchestrator:303 - Latency: 18336ms
# 2026-04-23 20:39:10.496 | INFO     | src.agents.orchestrator:agent_orchestrator:304 - Total Tokens: 668
# 2026-04-23 20:39:10.496 | INFO     | src.agents.orchestrator:agent_orchestrator:305 - Total Token Cost: $0.000147
# ====================================================================================================

# %%
complex_queries=[
##"Top 5 departments by revenue",
##"Top 3 doctors with highest number of appointments",
##"Total revenue generated per doctor",
"Patients with most admissions",
##"Departments with highest number of patients",
]

for query in complex_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:44:19.264 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:44:22.128 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:44:22.129 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:44:22.129 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:44:22.971 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:44:22.972 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:44:22.972 | WARNING  | src.agents.orchestrator:agent_orchestrator:209 - Query is ambiguous, starting refinement
# 2026-04-23 20:44:22.973 | INFO     | src.agents.sql_generator:refine_query:522 - Refinement iteration 1
# 2026-04-23 20:45:23.719 | DEBUG    | src.agents.sql_generator:refine_query:545 - Refine user query
# 2026-04-23 20:45:23.721 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:45:24.951 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:45:24.952 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:45:24.952 | INFO     | src.agents.sql_generator:refine_query:554 - Query refinement completed successfully
# 2026-04-23 20:45:24.954 | INFO     | src.agents.orchestrator:agent_orchestrator:217 - Refined user query
# 2026-04-23 20:45:24.954 | INFO     | src.agents.orchestrator:agent_orchestrator:218 - Refinement iterations: 1
# 2026-04-23 20:45:24.955 | INFO     | src.agents.orchestrator:agent_orchestrator:221 - SQL generator agent is called
# 2026-04-23 20:45:27.176 | INFO     | src.agents.orchestrator:agent_orchestrator:233 - SQL generator agent is completed
# 2026-04-23 20:45:27.177 | INFO     | src.agents.orchestrator:agent_orchestrator:236 - Generated SQL query: SELECT p.patient_id, p.first_name, p.last_name, COUNT(a.admission_id) AS admission_count
# FROM patients p
# JOIN admissions a ON p.patient_id = a.patient_id
# GROUP BY p.patient_id, p.first_name, p.last_name
# ORDER BY admission_count DESC
# LIMIT 1;
# 2026-04-23 20:45:27.177 | INFO     | src.agents.orchestrator:agent_orchestrator:238 - User query: Refined Query: List the patients who have the highest number of hospital admissions.
# 2026-04-23 20:45:27.179 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:45:27.179 | INFO     | src.infrastructure.guardrails.guardrails:_is_select:171 - SQL query is safe. Proceeding to syntax checking
# 2026-04-23 20:45:27.970 | DEBUG    | src.infrastructure.guardrails.guardrails:_is_query_syntax_valid:221 - LLM syntax response
# 2026-04-23 20:45:27.970 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:276 - SQL query syntax varified.Processing for database execution
# 2026-04-23 20:45:27.971 | INFO     | src.agents.orchestrator:agent_orchestrator:244 - SQL query is safe and valid
# 2026-04-23 20:45:27.972 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:110 - Executing SQL query on Supabase database
# 2026-04-23 20:45:29.044 | INFO     | src.infrastructure.db.supabase_client:_execute_sql_query:128 - ✅ Query executed successfully: 1 rows returned
# 2026-04-23 20:45:29.045 | INFO     | src.agents.orchestrator:agent_orchestrator:253 - Latency: 69780ms
# 2026-04-23 20:45:29.045 | INFO     | src.agents.orchestrator:agent_orchestrator:254 - Total Tokens: 688
# 2026-04-23 20:45:29.046 | INFO     | src.agents.orchestrator:agent_orchestrator:255 - Total Token Cost: $0.000144
# ====================================================================================================

# %%
edge_cases=[
##"Top departments",
##"Patient details",
##"Doctor performance",
"Revenue analysis",
]

for query in edge_cases:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:56:52.101 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:56:56.211 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:56:56.213 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:56:56.214 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:56:56.925 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:56:56.926 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:56:56.926 | WARNING  | src.agents.orchestrator:agent_orchestrator:209 - Query is ambiguous, starting refinement
# 2026-04-23 20:56:56.927 | INFO     | src.agents.sql_generator:refine_query:522 - Refinement iteration 1
# 2026-04-23 20:57:08.933 | DEBUG    | src.agents.sql_generator:refine_query:545 - Refine user query
# 2026-04-23 20:57:08.934 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:57:10.403 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:57:10.404 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:57:10.405 | WARNING  | src.agents.sql_generator:refine_query:549 - Refined query is ambiguous, continuing refinement
# 2026-04-23 20:57:10.406 | INFO     | src.agents.sql_generator:refine_query:522 - Refinement iteration 2
# 2026-04-23 20:57:24.179 | DEBUG    | src.agents.sql_generator:refine_query:545 - Refine user query
# 2026-04-23 20:57:24.179 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:57:25.084 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:57:25.087 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:57:25.088 | WARNING  | src.agents.sql_generator:refine_query:549 - Refined query is ambiguous, continuing refinement
# 2026-04-23 20:57:25.088 | INFO     | src.agents.sql_generator:refine_query:522 - Refinement iteration 3
# 2026-04-23 20:57:30.103 | DEBUG    | src.agents.sql_generator:refine_query:545 - Refine user query
# 2026-04-23 20:57:30.104 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:57:31.169 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:57:31.169 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:57:31.170 | WARNING  | src.agents.sql_generator:refine_query:549 - Refined query is ambiguous, continuing refinement
# 2026-04-23 20:57:31.170 | WARNING  | src.agents.sql_generator:refine_query:566 - Max refinement attempts reached
# 2026-04-23 20:57:31.172 | WARNING  | src.agents.orchestrator:agent_orchestrator:267 - Query is not refined.Please Try Again Later!!!!!
# ====================================================================================================

# %%
out_of_scope_queries=[
##"What is this system?",
##"Tell me a joke",
##"Who are you?",
##"Drop all tables",
"Delete patient records",
]

for query in out_of_scope_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-23 20:47:31.313 | INFO     | src.agents.orchestrator:agent_orchestrator:193 - Router intent agent is called
# 2026-04-23 20:47:34.130 | INFO     | src.agents.orchestrator:agent_orchestrator:201 - Router intent agent is completed
# 2026-04-23 20:47:34.130 | INFO     | src.agents.orchestrator:agent_orchestrator:205 - Checking SQL query ambiguity
# 2026-04-23 20:47:34.131 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:47:34.841 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:47:34.841 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-23 20:47:34.842 | WARNING  | src.agents.orchestrator:agent_orchestrator:209 - Query is ambiguous, starting refinement
# 2026-04-23 20:47:34.843 | INFO     | src.agents.sql_generator:refine_query:522 - Refinement iteration 1
# 2026-04-23 20:47:46.464 | DEBUG    | src.agents.sql_generator:refine_query:545 - Refine user query
# 2026-04-23 20:47:46.465 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-23 20:47:47.243 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-23 20:47:47.243 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-23 20:47:47.244 | INFO     | src.agents.sql_generator:refine_query:554 - Query refinement completed successfully
# 2026-04-23 20:47:47.244 | INFO     | src.agents.orchestrator:agent_orchestrator:217 - Refined user query
# 2026-04-23 20:47:47.245 | INFO     | src.agents.orchestrator:agent_orchestrator:218 - Refinement iterations: 1
# 2026-04-23 20:47:47.245 | INFO     | src.agents.orchestrator:agent_orchestrator:221 - SQL generator agent is called
# 2026-04-23 20:47:48.450 | INFO     | src.agents.orchestrator:agent_orchestrator:233 - SQL generator agent is completed
# 2026-04-23 20:47:48.450 | INFO     | src.agents.orchestrator:agent_orchestrator:236 - Generated SQL query: DELETE FROM patients;
# 2026-04-23 20:47:48.451 | INFO     | src.agents.orchestrator:agent_orchestrator:238 - User query: Refined Query: Permanently delete all patient records from the database.
# 2026-04-23 20:47:48.452 | INFO     | src.infrastructure.guardrails.guardrails:is_validate:264 - Starting SQL Guardrails
# 2026-04-23 20:47:48.452 | WARNING  | src.infrastructure.guardrails.guardrails:_is_prohibited:133 - Prohibited SQL query detected: DELETE
# 2026-04-23 20:47:48.453 | WARNING  | src.infrastructure.guardrails.guardrails:is_validate:271 - SQL query is not safe. Rejecting the query from system
# 2026-04-23 20:47:48.454 | INFO     | src.agents.orchestrator:agent_orchestrator:253 - Latency: 17141ms
# 2026-04-23 20:47:48.455 | INFO     | src.agents.orchestrator:agent_orchestrator:254 - Total Tokens: 561
# 2026-04-23 20:47:48.456 | INFO     | src.agents.orchestrator:agent_orchestrator:255 - Total Token Cost: $0.000097
# ====================================================================================================

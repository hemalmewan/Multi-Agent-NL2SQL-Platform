# %% [markdown]
# ## **Import Required Libraries**

# %%
import os
import time
import sys
from pathlib import Path
from dotenv import load_dotenv

## Define project root
_PROJECT_ROOT=Path.cwd().parent
sys.path.insert(0,str(_PROJECT_ROOT))

## Load enviromental variables
load_dotenv(_PROJECT_ROOT/".env")

##====================================
## Import User Define Python Modules
##====================================
from src.infrastructure.config import (
    validate,
    dump
)
from src.agents.intent_router import RouterIntent
from src.agents.sql_generator import SQLGenerator
from src.infrastructure.llm.llm_providers import _global_llm_provider,_llm_service_provider
from src.agents.orchestrator import Orchestrator
from scripts.test_supabase import main

# %%
# Validate and display config
try:
    validate()
    main()
    dump()
except Exception as e:
    print(f"⚠️  Config note: {e}")

print(f"✅ Enviromental Loaded.")
print(f"📁 Project root: {_PROJECT_ROOT}")
# Out:
# 2026-04-27 00:03:30.927 | INFO     | src.infrastructure.config:validate:410 - All required environment variables are set
# 2026-04-27 00:03:30.929 | INFO     | scripts.test_supabase:main:17 - Testing database connection…
# 2026-04-27 00:03:31.045 | INFO     | src.infrastructure.db.sql_client:_supabase_sql_engine:124 - ✓ Supabase SQL engine created
# 2026-04-27 00:03:34.384 | INFO     | src.infrastructure.db.supabase_client:_test_connection:229 - ✅ Supabase connection test: SUCCESS
# 2026-04-27 00:03:34.386 | SUCCESS  | scripts.test_supabase:main:21 - All checks passed! Supabase is ready.
# ...
# CONFIGURATION (NON-SECRETS ONLY)
# ...
#
# 🌐 Provider:
#    Provider: openrouter
#    Model Tier: general
#    Openrouter Base URL: https://openrouter.ai/api/v1
#    Chat Model: openai/gpt-4o-mini
# ...
#
# ✅ Enviromental Loaded.
# 📁 Project root: c:\UOC pdf\AI Engineering Bootcamp\mini-project-04

# %%
llm=_llm_service_provider()
orchestrator=Orchestrator(llm=llm)

# %%
basic_user_query=[
"List all patients",
#"Show all doctors",
#"List all departments",
#"Show all staff members",
]

for query in basic_user_query:
    result=orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:38:58.197 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:39:01.674 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:39:01.676 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:39:01.676 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:39:02.290 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:39:02.290 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-26 23:39:02.294 | INFO     | src.agents.orchestrator:_sql_generation_agent:600 - SQL generator agent is called
# 2026-04-26 23:39:03.499 | INFO     | src.agents.orchestrator:_sql_generation_agent:621 - SQL generator agent is completed
# ...

# %%
intermidiate_user_query=[
#"Show patients older than 60",
"List doctors with specialty cardiology",
#"Show appointments scheduled today",
#"List admissions in the last 7 days",
]

for query in intermidiate_user_query:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:40:31.814 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:40:37.877 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:40:37.878 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:40:37.880 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:40:38.894 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:40:38.895 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-26 23:40:38.897 | INFO     | src.agents.orchestrator:_sql_generation_agent:600 - SQL generator agent is called
# 2026-04-26 23:40:46.053 | INFO     | src.agents.orchestrator:_sql_generation_agent:621 - SQL generator agent is completed
# ...

# %%
aggregation_queries=[
#"Total revenue generated",
#"Count of patients",
"Average patient age",
#"Total number of appointments",
]

for query in aggregation_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:43:45.272 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:43:48.469 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:43:48.470 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:43:48.471 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:43:49.433 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:43:49.433 | WARNING  | src.agents.sql_generator:_check_ambiguity:446 - Query classified as AMBIGUOUS/INVALID
# 2026-04-26 23:43:49.435 | WARNING  | src.agents.orchestrator:_query_refinement:551 - Query is ambiguous, starting refinement
# 2026-04-26 23:43:49.435 | INFO     | src.agents.sql_generator:refine_query:542 - Refinement iteration 1
# ...

# %%
group_by_queries=[
"Total revenue by department",
##"Number of patients per department",
##"Count of appointments per doctor",
##"Total payments by month",
]

for query in group_by_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:44:20.321 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:44:21.287 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:44:21.289 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:44:21.289 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:44:22.009 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:44:22.010 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-26 23:44:22.011 | INFO     | src.agents.orchestrator:_sql_generation_agent:600 - SQL generator agent is called
# 2026-04-26 23:44:22.012 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# ...

# %%
join_queries=[
##"List patients with their doctors",
"Show appointments with patient and doctor names",
##"List billing invoices with department names",
##"Show payments with invoice details",
]

for query in join_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:44:45.909 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:44:47.728 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:44:47.730 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:44:47.732 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:44:48.588 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:44:48.589 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-26 23:44:48.590 | INFO     | src.agents.orchestrator:_sql_generation_agent:600 - SQL generator agent is called
# 2026-04-26 23:44:50.819 | INFO     | src.agents.orchestrator:_sql_generation_agent:621 - SQL generator agent is completed
# ...

# %%
complex_queries=[
##"Top 5 departments by revenue",
##"Top 3 doctors with highest number of appointments",
##"Total revenue generated per doctor",
"Patients with most admissions",
##"Departments with highest number of patients",
]

for query in complex_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:47:28.877 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:47:32.468 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:47:32.469 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:47:32.470 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:47:33.523 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:47:33.524 | WARNING  | src.agents.sql_generator:_check_ambiguity:446 - Query classified as AMBIGUOUS/INVALID
# 2026-04-26 23:47:33.527 | WARNING  | src.agents.orchestrator:_query_refinement:551 - Query is ambiguous, starting refinement
# 2026-04-26 23:47:33.527 | INFO     | src.agents.sql_generator:refine_query:542 - Refinement iteration 1
# ...

# %%
edge_cases=[
##"Top departments",
##"Patient details",
##"Doctor performance",
"Revenue analysis",
]

for query in edge_cases:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-25 14:13:01.564 | INFO     | src.agents.orchestrator:_router_intent_agent:408 - Router intent agent is called
# 2026-04-25 14:13:02.774 | INFO     | src.agents.orchestrator:_router_intent_agent:427 - Router intent agent is completed
# 2026-04-25 14:13:02.776 | INFO     | src.agents.orchestrator:_query_ambiguity_check:442 - Checking SQL query ambiguity
# 2026-04-25 14:13:02.777 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-25 14:13:05.406 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-25 14:13:05.407 | WARNING  | src.agents.sql_generator:_check_ambiguity:446 - Query classified as AMBIGUOUS/INVALID
# 2026-04-25 14:13:05.408 | WARNING  | src.agents.orchestrator:_query_refinement:472 - Query is ambiguous, starting refinement
# 2026-04-25 14:13:05.409 | INFO     | src.agents.sql_generator:refine_query:542 - Refinement iteration 1
# ...

# %%
out_of_scope_queries=[
##"What is this system?",
##"Tell me a joke",
##"Who are you?",
##"Drop all tables",
"Delete patient records",
]

for query in out_of_scope_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-26 23:48:22.864 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-26 23:48:24.068 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-26 23:48:24.072 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-26 23:48:24.072 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-26 23:48:24.971 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-26 23:48:24.972 | WARNING  | src.agents.sql_generator:_check_ambiguity:446 - Query classified as AMBIGUOUS/INVALID
# 2026-04-26 23:48:24.974 | WARNING  | src.agents.orchestrator:_query_refinement:551 - Query is ambiguous, starting refinement
# 2026-04-26 23:48:24.975 | INFO     | src.agents.sql_generator:refine_query:542 - Refinement iteration 1
# ...

# %%
more_queries=[
    "“Show the number of patients grouped by gender"
]

for query in more_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-27 00:03:42.017 | INFO     | src.agents.orchestrator:_router_intent_agent:448 - Router intent agent is called
# 2026-04-27 00:03:45.839 | INFO     | src.agents.orchestrator:_router_intent_agent:469 - Router intent agent is completed
# 2026-04-27 00:03:45.842 | INFO     | src.agents.orchestrator:_query_ambiguity_check:498 - Checking SQL query ambiguity
# 2026-04-27 00:03:45.843 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-27 00:03:46.876 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-27 00:03:46.877 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-27 00:03:46.878 | INFO     | src.agents.orchestrator:_sql_generation_agent:600 - SQL generator agent is called
# 2026-04-27 00:03:48.136 | INFO     | src.agents.orchestrator:_sql_generation_agent:621 - SQL generator agent is completed
# ...

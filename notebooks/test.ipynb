# %% [markdown]
# ## **Import Required Libraries**

# %%
import os
import time
import sys
from pathlib import Path
from dotenv import load_dotenv

## Define project root
_PROJECT_ROOT=Path.cwd().parent
sys.path.insert(0,str(_PROJECT_ROOT))

## Load enviromental variables
load_dotenv(_PROJECT_ROOT/".env")

##====================================
## Import User Define Python Modules
##====================================
from src.infrastructure.config import (
    validate,
    dump
)
from src.agents.intent_router import RouterIntent
from src.agents.sql_generator import SQLGenerator
from src.infrastructure.llm.llm_providers import _global_llm_provider,_llm_service_provider
from src.agents.orchestrator import Orchestrator

# %%
# Validate and display config
try:
    validate()
    dump()
except Exception as e:
    print(f"⚠️  Config note: {e}")

print(f"✅ Enviromental Loaded.")
print(f"📁 Project root: {_PROJECT_ROOT}")
# Out:
# 2026-04-22 21:36:29.303 | INFO     | src.infrastructure.config:validate:410 - All required environment variables are set
# ============================================================
# CONFIGURATION (NON-SECRETS ONLY)
# ============================================================
#
# 🌐 Provider:
#    Provider: openrouter
#    Model Tier: general
#    Openrouter Base URL: https://openrouter.ai/api/v1
#    Chat Model: openai/gpt-4o-mini
# ============================================================
#
# ✅ Enviromental Loaded.
# 📁 Project root: c:\UOC pdf\AI Engineering Bootcamp\mini-project-04

# %%
llm=_llm_service_provider()
orchestrator=Orchestrator(llm=llm)

basic_user_query=[
"List all patients",
"Show all doctors",
"List all departments",
"Show all staff members",
]

for query in basic_user_query:
    result=orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:36:32.875 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:36:34.858 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:36:34.858 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:36:34.859 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:36:36.554 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:36:36.555 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:36:36.555 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:36:37.725 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:36:37.725 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM patients;
# 2026-04-22 21:36:37.726 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List all patients
# 2026-04-22 21:36:37.726 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 4850ms
# 2026-04-22 21:36:37.727 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 466
# 2026-04-22 21:36:37.727 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000076
# 2026-04-22 21:36:37.728 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:36:38.438 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:36:38.438 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:36:38.439 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:36:39.155 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:36:39.156 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:36:39.157 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:36:40.639 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:36:40.641 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM doctors;
# 2026-04-22 21:36:40.642 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show all doctors
# 2026-04-22 21:36:40.642 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2914ms
# 2026-04-22 21:36:40.642 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 453
# 2026-04-22 21:36:40.644 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000074
# 2026-04-22 21:36:40.644 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:36:41.727 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:36:41.728 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:36:41.728 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:36:42.534 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:36:42.536 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:36:42.537 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:36:43.356 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:36:43.357 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM departments;
# 2026-04-22 21:36:43.357 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List all departments
# 2026-04-22 21:36:43.357 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2713ms
# 2026-04-22 21:36:43.358 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 434
# 2026-04-22 21:36:43.359 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000072
# 2026-04-22 21:36:43.359 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:36:44.396 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:36:44.397 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:36:44.397 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:36:45.169 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:36:45.169 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:36:45.171 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:36:46.237 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:36:46.238 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM staff;
# 2026-04-22 21:36:46.238 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show all staff members
# 2026-04-22 21:36:46.239 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2880ms
# 2026-04-22 21:36:46.239 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 450
# 2026-04-22 21:36:46.240 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000075
# ====================================================================================================

# %%
intermidiate_user_query=[
"Show patients older than 60",
"List doctors with specialty cardiology",
"Show appointments scheduled today",
"List admissions in the last 7 days",
]

for query in intermidiate_user_query:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:37:35.751 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:37:37.970 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:37:37.971 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:37:37.971 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:37:38.819 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:37:38.820 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:37:38.820 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:37:40.058 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:37:40.059 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM patients
# WHERE age(current_date, date_of_birth) > interval '60 years';
# 2026-04-22 21:37:40.060 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show patients older than 60
# 2026-04-22 21:37:40.060 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 4309ms
# 2026-04-22 21:37:40.061 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 489
# 2026-04-22 21:37:40.062 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000087
# 2026-04-22 21:37:40.062 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:37:40.881 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:37:40.883 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:37:40.884 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:37:41.727 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:37:41.728 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:37:41.729 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:37:43.175 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:37:43.176 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT d.doctor_id, d.first_name, d.last_name, d.phone, d.email
# FROM doctors d
# JOIN specialties s ON d.specialty_id = s.specialty_id
# WHERE LOWER(s.specialty_name) = 'cardiology';
# 2026-04-22 21:37:43.178 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List doctors with specialty cardiology
# 2026-04-22 21:37:43.178 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 3115ms
# 2026-04-22 21:37:43.179 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 536
# 2026-04-22 21:37:43.179 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000107
# 2026-04-22 21:37:43.180 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:37:44.129 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:37:44.130 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:37:44.130 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:37:44.997 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:37:44.997 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:37:44.998 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:37:45.939 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:37:45.940 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT *
# FROM appointments
# WHERE appointment_date = CURRENT_DATE;
# 2026-04-22 21:37:45.940 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show appointments scheduled today
# 2026-04-22 21:37:45.941 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2761ms
# 2026-04-22 21:37:45.941 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 454
# 2026-04-22 21:37:45.941 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000078
# 2026-04-22 21:37:45.943 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:37:46.695 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:37:46.695 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:37:46.696 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:37:47.622 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:37:47.623 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:37:47.623 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:37:48.816 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:37:48.817 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT *
# FROM admissions
# WHERE admission_date >= CURRENT_DATE - INTERVAL '7 days';
# 2026-04-22 21:37:48.817 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List admissions in the last 7 days
# 2026-04-22 21:37:48.817 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2874ms
# 2026-04-22 21:37:48.818 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 481
# 2026-04-22 21:37:48.818 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000085
# ====================================================================================================

# %%
aggregation_queries=[
"Total revenue generated",
"Count of patients",
"Average patient age",
"Total number of appointments",
]

for query in aggregation_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:38:09.022 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:38:10.129 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:38:10.130 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:38:10.130 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:38:10.931 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:38:10.932 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 21:38:10.932 | WARNING  | src.agents.orchestrator:agent_orchestrator:54 - Query is ambiguous, starting refinement
# 2026-04-22 21:38:10.933 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 1
# 2026-04-22 21:38:41.461 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 21:38:41.461 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:38:42.173 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:38:42.173 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:38:42.173 | INFO     | src.agents.sql_generator:refine_query:507 - Query refinement completed successfully
# 2026-04-22 21:38:42.175 | INFO     | src.agents.orchestrator:agent_orchestrator:62 - Refined user query
# 2026-04-22 21:38:42.175 | INFO     | src.agents.orchestrator:agent_orchestrator:63 - Refinement iterations: 1
# 2026-04-22 21:38:42.175 | INFO     | src.agents.orchestrator:agent_orchestrator:66 - SQL generator agent is called
# 2026-04-22 21:38:42.176 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 21:38:42.176 | WARNING  | src.agents.orchestrator:agent_orchestrator:70 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:38:42.177 | INFO     | src.agents.orchestrator:agent_orchestrator:77 - SQL generator agent is completed
# 2026-04-22 21:38:42.177 | INFO     | src.agents.orchestrator:agent_orchestrator:80 - Generated SQL query:
# 2026-04-22 21:38:42.178 | INFO     | src.agents.orchestrator:agent_orchestrator:82 - User query: Refined Query: What is the total revenue generated by each department?
# 2026-04-22 21:38:42.179 | INFO     | src.agents.orchestrator:agent_orchestrator:88 - Latency: 33157ms
# 2026-04-22 21:38:42.180 | INFO     | src.agents.orchestrator:agent_orchestrator:89 - Total Tokens: 336
# 2026-04-22 21:38:42.181 | INFO     | src.agents.orchestrator:agent_orchestrator:90 - Total Token Cost: $0.000059
# 2026-04-22 21:38:42.182 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:38:42.915 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:38:42.916 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:38:42.916 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:38:43.614 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:38:43.615 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:38:43.616 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:38:44.534 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:38:44.536 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT COUNT(*) AS patient_count FROM patients;
# 2026-04-22 21:38:44.536 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Count of patients
# 2026-04-22 21:38:44.537 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2355ms
# 2026-04-22 21:38:44.538 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 470
# 2026-04-22 21:38:44.538 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000079
# 2026-04-22 21:38:44.539 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:38:45.500 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:38:45.500 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:38:45.501 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:38:46.125 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:38:46.125 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:38:46.126 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:38:47.339 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:38:47.339 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT AVG(EXTRACT(YEAR FROM AGE(date_of_birth))) AS average_age FROM patients;
# 2026-04-22 21:38:47.340 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Average patient age
# 2026-04-22 21:38:47.341 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2801ms
# 2026-04-22 21:38:47.341 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 480
# 2026-04-22 21:38:47.342 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000085
# 2026-04-22 21:38:47.342 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:38:48.140 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:38:48.140 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:38:48.141 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:38:48.882 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:38:48.883 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:38:48.884 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:38:50.056 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:38:50.057 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT COUNT(*) AS total_appointments FROM appointments;
# 2026-04-22 21:38:50.057 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Total number of appointments
# 2026-04-22 21:38:50.058 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2715ms
# 2026-04-22 21:38:50.059 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 451
# 2026-04-22 21:38:50.059 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000077
# ====================================================================================================

# %%
group_by_queries=[
"Total revenue by department",
"Number of patients per department",
"Count of appointments per doctor",
"Total payments by month",
]

for query in group_by_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:39:55.745 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:39:57.578 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:39:57.579 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:39:57.579 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:39:58.531 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:39:58.532 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:39:58.532 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:39:58.533 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 21:39:58.534 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:39:58.535 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:39:58.535 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 21:39:58.536 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Total revenue by department
# 2026-04-22 21:39:58.536 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2791ms
# 2026-04-22 21:39:58.537 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 249
# 2026-04-22 21:39:58.537 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000040
# 2026-04-22 21:39:58.538 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:39:59.436 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:39:59.436 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:39:59.437 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:40:00.195 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:40:00.196 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:40:00.196 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:40:00.197 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 21:40:00.197 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:40:00.197 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:40:00.198 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 21:40:00.198 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Number of patients per department
# 2026-04-22 21:40:00.200 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 1661ms
# 2026-04-22 21:40:00.200 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 249
# 2026-04-22 21:40:00.201 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000040
# 2026-04-22 21:40:00.201 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:40:01.263 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:40:01.264 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:40:01.265 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:40:02.036 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:40:02.036 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:40:02.037 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:40:03.997 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:40:04.000 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT d.doctor_id, d.first_name, d.last_name, COUNT(a.appointment_id) AS appointment_count
# FROM doctors d
# LEFT JOIN appointments a ON d.doctor_id = a.doctor_id
# GROUP BY d.doctor_id, d.first_name, d.last_name;
# 2026-04-22 21:40:04.001 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Count of appointments per doctor
# 2026-04-22 21:40:04.001 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 3800ms
# 2026-04-22 21:40:04.002 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 557
# 2026-04-22 21:40:04.002 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000114
# 2026-04-22 21:40:04.004 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:40:05.138 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:40:05.139 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:40:05.139 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:40:05.757 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:40:05.757 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:40:05.758 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:40:07.373 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:40:07.373 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT DATE_TRUNC('month', payment_date) AS month, SUM(amount) AS total_payments
# FROM payments
# GROUP BY month
# ORDER BY month;
# 2026-04-22 21:40:07.374 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Total payments by month
# 2026-04-22 21:40:07.374 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 3370ms
# 2026-04-22 21:40:07.375 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 473
# 2026-04-22 21:40:07.375 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000090
# ====================================================================================================

# %%
join_queries=[
"List patients with their doctors",
"Show appointments with patient and doctor names",
"List billing invoices with department names",
"Show payments with invoice details",
]

for query in join_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:44:04.753 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:44:08.258 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:44:08.258 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:44:08.259 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:44:09.180 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:44:09.181 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:44:09.181 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:44:09.182 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 21:44:09.183 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:44:09.183 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:44:09.184 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 21:44:09.184 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List patients with their doctors
# 2026-04-22 21:44:09.184 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 4431ms
# 2026-04-22 21:44:09.184 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 251
# 2026-04-22 21:44:09.186 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000040
# 2026-04-22 21:44:09.186 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:44:10.676 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:44:10.678 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:44:10.678 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:44:11.377 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:44:11.378 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:44:11.378 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:44:13.678 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:44:13.678 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT a.appointment_id,
#        p.first_name AS patient_first_name,
#        p.last_name AS patient_last_name,
#        d.first_name AS doctor_first_name,
#        d.last_name AS doctor_last_name,
#        a.appointment_date,
#        a.appointment_time,
#        a.reason,
#        a.status
# FROM appointments a
# JOIN patients p ON a.patient_id = p.patient_id
# JOIN doctors d ON a.doctor_id = d.doctor_id;
# 2026-04-22 21:44:13.679 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show appointments with patient and doctor names
# 2026-04-22 21:44:13.679 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 4492ms
# 2026-04-22 21:44:13.679 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 674
# 2026-04-22 21:44:13.680 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000151
# 2026-04-22 21:44:13.680 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:44:14.516 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:44:14.517 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:44:14.517 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:44:15.523 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:44:15.525 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:44:15.526 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:44:15.527 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 21:44:15.528 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:44:15.528 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:44:15.530 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 21:44:15.531 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: List billing invoices with department names
# 2026-04-22 21:44:15.531 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 1851ms
# 2026-04-22 21:44:15.532 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 251
# 2026-04-22 21:44:15.533 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000040
# 2026-04-22 21:44:15.533 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:44:17.196 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:44:17.198 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:44:17.198 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:44:17.953 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:44:17.954 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:44:17.954 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:44:25.489 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:44:25.489 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT p.payment_id, p.invoice_id, p.patient_id, p.payment_date, p.amount, p.payment_method, p.transaction_reference, p.status,
#        b.admission_id, b.invoice_date, b.total_amount, b.discount, b.tax, b.net_amount, b.status AS invoice_status, b.due_date
# FROM payments p
# JOIN billing_invoices b ON p.invoice_id = b.invoice_id;
# 2026-04-22 21:44:25.490 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Show payments with invoice details
# 2026-04-22 21:44:25.490 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 9957ms
# 2026-04-22 21:44:25.492 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 584
# 2026-04-22 21:44:25.492 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000130
# ====================================================================================================

# %%
complex_queries=[
"Top 5 departments by revenue",
"Top 3 doctors with highest number of appointments",
"Total revenue generated per doctor",
"Patients with most admissions",
"Departments with highest number of patients",
]

for query in complex_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 22:25:31.034 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 22:25:53.076 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:25:53.078 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:25:53.079 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:25:53.905 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:25:53.906 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:25:53.908 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 22:25:53.910 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 22:25:53.911 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 22:25:53.913 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 22:25:53.913 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 22:25:53.914 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Top 5 departments by revenue
# 2026-04-22 22:25:53.915 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 22880ms
# 2026-04-22 22:25:53.916 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 252
# 2026-04-22 22:25:53.916 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000041
# 2026-04-22 22:25:53.917 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:25:55.268 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:25:55.270 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:25:55.271 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:25:56.255 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:25:56.257 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:25:56.259 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 22:25:58.569 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 22:25:58.570 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT d.doctor_id, d.first_name, d.last_name, COUNT(a.appointment_id) AS appointment_count
# FROM doctors d
# LEFT JOIN appointments a ON d.doctor_id = a.doctor_id
# GROUP BY d.doctor_id, d.first_name, d.last_name
# ORDER BY appointment_count DESC
# LIMIT 3;
# 2026-04-22 22:25:58.572 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Top 3 doctors with highest number of appointments
# 2026-04-22 22:25:58.572 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 4654ms
# 2026-04-22 22:25:58.573 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 576
# 2026-04-22 22:25:58.574 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000122
# 2026-04-22 22:25:58.575 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:25:59.542 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:25:59.543 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:25:59.545 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:26:00.566 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:26:00.567 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:26:00.568 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 22:26:00.569 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 22:26:00.570 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 22:26:00.570 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 22:26:00.572 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 22:26:00.573 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Total revenue generated per doctor
# 2026-04-22 22:26:00.574 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 1999ms
# 2026-04-22 22:26:00.575 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 251
# 2026-04-22 22:26:00.575 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000040
# 2026-04-22 22:26:00.577 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:26:02.268 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:26:02.269 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:26:02.271 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:26:03.394 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:26:03.396 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:26:03.396 | WARNING  | src.agents.orchestrator:agent_orchestrator:54 - Query is ambiguous, starting refinement
# 2026-04-22 22:26:03.397 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 1
# 2026-04-22 22:26:48.859 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 22:26:48.860 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:26:49.735 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:26:49.736 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:26:49.737 | INFO     | src.agents.sql_generator:refine_query:507 - Query refinement completed successfully
# 2026-04-22 22:26:49.738 | INFO     | src.agents.orchestrator:agent_orchestrator:62 - Refined user query
# 2026-04-22 22:26:49.738 | INFO     | src.agents.orchestrator:agent_orchestrator:63 - Refinement iterations: 1
# 2026-04-22 22:26:49.738 | INFO     | src.agents.orchestrator:agent_orchestrator:66 - SQL generator agent is called
# 2026-04-22 22:26:51.952 | INFO     | src.agents.orchestrator:agent_orchestrator:77 - SQL generator agent is completed
# 2026-04-22 22:26:51.953 | INFO     | src.agents.orchestrator:agent_orchestrator:80 - Generated SQL query: SELECT p.patient_id, p.first_name, p.last_name, COUNT(a.admission_id) AS admission_count
# FROM patients p
# JOIN admissions a ON p.patient_id = a.patient_id
# GROUP BY p.patient_id, p.first_name, p.last_name
# ORDER BY admission_count DESC
# LIMIT 1;
# 2026-04-22 22:26:51.956 | INFO     | src.agents.orchestrator:agent_orchestrator:82 - User query: Refined Query: Identify the patients with the highest number of admissions.
# 2026-04-22 22:26:51.956 | INFO     | src.agents.orchestrator:agent_orchestrator:88 - Latency: 51378ms
# 2026-04-22 22:26:51.957 | INFO     | src.agents.orchestrator:agent_orchestrator:89 - Total Tokens: 682
# 2026-04-22 22:26:51.957 | INFO     | src.agents.orchestrator:agent_orchestrator:90 - Total Token Cost: $0.000141
# 2026-04-22 22:26:51.958 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:26:53.150 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:26:53.151 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:26:53.152 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:26:54.386 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:26:54.387 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:26:54.388 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 22:26:54.388 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 22:26:54.388 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 22:26:54.389 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 22:26:54.389 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 22:26:54.390 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Departments with highest number of patients
# 2026-04-22 22:26:54.391 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2433ms
# 2026-04-22 22:26:54.391 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 252
# 2026-04-22 22:26:54.392 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000041
# ====================================================================================================

# %%
edge_cases=[
"Top departments",
"Patient details",
"Doctor performance",
"Revenue analysis",
]

for query in edge_cases:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 22:28:20.765 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 22:28:22.139 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:28:22.141 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:28:22.141 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:28:23.166 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:28:23.167 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:28:23.168 | WARNING  | src.agents.orchestrator:agent_orchestrator:54 - Query is ambiguous, starting refinement
# 2026-04-22 22:28:23.170 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 1
# 2026-04-22 22:28:39.888 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 22:28:39.890 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:28:40.767 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:28:40.767 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:28:40.768 | INFO     | src.agents.sql_generator:refine_query:507 - Query refinement completed successfully
# 2026-04-22 22:28:40.768 | INFO     | src.agents.orchestrator:agent_orchestrator:62 - Refined user query
# 2026-04-22 22:28:40.769 | INFO     | src.agents.orchestrator:agent_orchestrator:63 - Refinement iterations: 1
# 2026-04-22 22:28:40.769 | INFO     | src.agents.orchestrator:agent_orchestrator:66 - SQL generator agent is called
# 2026-04-22 22:28:40.770 | WARNING  | src.agents.sql_generator:generate_sql:183 - Multiple tables found but no relationships
# 2026-04-22 22:28:40.771 | WARNING  | src.agents.orchestrator:agent_orchestrator:70 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 22:28:40.772 | INFO     | src.agents.orchestrator:agent_orchestrator:77 - SQL generator agent is completed
# 2026-04-22 22:28:40.772 | INFO     | src.agents.orchestrator:agent_orchestrator:80 - Generated SQL query:
# 2026-04-22 22:28:40.773 | INFO     | src.agents.orchestrator:agent_orchestrator:82 - User query: Refined Query: Top departments ranked by the number of appointments.
# 2026-04-22 22:28:40.773 | INFO     | src.agents.orchestrator:agent_orchestrator:88 - Latency: 20007ms
# 2026-04-22 22:28:40.773 | INFO     | src.agents.orchestrator:agent_orchestrator:89 - Total Tokens: 328
# 2026-04-22 22:28:40.774 | INFO     | src.agents.orchestrator:agent_orchestrator:90 - Total Token Cost: $0.000057
# 2026-04-22 22:28:40.774 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:28:41.736 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:28:41.737 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:28:41.737 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:28:42.510 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:28:42.511 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 22:28:42.511 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 22:28:43.696 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 22:28:43.697 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query: SELECT * FROM patients;
# 2026-04-22 22:28:43.697 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Patient details
# 2026-04-22 22:28:43.698 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 2924ms
# 2026-04-22 22:28:43.699 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 464
# 2026-04-22 22:28:43.700 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000076
# 2026-04-22 22:28:43.702 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 22:28:44.791 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:28:44.791 | INFO     | src.agents.orchestrator:agent_orchestrator:145 - Not a SQL query
# 2026-04-22 22:28:44.792 | INFO     | src.agents.orchestrator:agent_orchestrator:146 - Latency: 1088ms
# 2026-04-22 22:28:44.792 | INFO     | src.agents.orchestrator:agent_orchestrator:147 - Total Tokens:248
# 2026-04-22 22:28:44.792 | INFO     | src.agents.orchestrator:agent_orchestrator:148 - Total Token Cost: $0.000040
# 2026-04-22 22:28:44.794 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
#
# ====================================================================================================
# 2026-04-22 22:28:45.727 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 22:28:45.728 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 22:28:45.729 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:28:47.389 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:28:47.390 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:28:47.390 | WARNING  | src.agents.orchestrator:agent_orchestrator:54 - Query is ambiguous, starting refinement
# 2026-04-22 22:28:47.391 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 1
# 2026-04-22 22:29:41.795 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 22:29:41.796 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:29:42.847 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:29:42.849 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:29:42.850 | WARNING  | src.agents.sql_generator:refine_query:502 - Refined query is ambiguous, continuing refinement
# 2026-04-22 22:29:42.851 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 2
# 2026-04-22 22:29:54.386 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 22:29:54.386 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:29:55.254 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:29:55.254 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:29:55.254 | WARNING  | src.agents.sql_generator:refine_query:502 - Refined query is ambiguous, continuing refinement
# 2026-04-22 22:29:55.256 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 3
# 2026-04-22 22:30:03.848 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 22:30:03.849 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 22:30:04.565 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 22:30:04.566 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 22:30:04.568 | WARNING  | src.agents.sql_generator:refine_query:502 - Refined query is ambiguous, continuing refinement
# 2026-04-22 22:30:04.568 | WARNING  | src.agents.sql_generator:refine_query:519 - Max refinement attempts reached
# 2026-04-22 22:30:04.570 | WARNING  | src.agents.orchestrator:agent_orchestrator:102 - Query is not refined.Please Try Again Later!!!!!
# ====================================================================================================

# %%
out_of_scope_queries=[
"What is this system?",
"Tell me a joke",
"Who are you?",
"Drop all tables",
"Delete patient records",
]

for query in out_of_scope_queries:
    orchestrator.agent_orchestrator(user_query=query)
    print("="*100)
# Out:
# 2026-04-22 21:42:09.664 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# 2026-04-22 21:42:13.152 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:42:13.152 | INFO     | src.agents.orchestrator:agent_orchestrator:145 - Not a SQL query
# 2026-04-22 21:42:13.153 | INFO     | src.agents.orchestrator:agent_orchestrator:146 - Latency: 3487ms
# 2026-04-22 21:42:13.153 | INFO     | src.agents.orchestrator:agent_orchestrator:147 - Total Tokens:250
# 2026-04-22 21:42:13.153 | INFO     | src.agents.orchestrator:agent_orchestrator:148 - Total Token Cost: $0.000040
# 2026-04-22 21:42:13.154 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
#
# ====================================================================================================
# 2026-04-22 21:42:15.137 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:42:15.138 | INFO     | src.agents.orchestrator:agent_orchestrator:145 - Not a SQL query
# 2026-04-22 21:42:15.138 | INFO     | src.agents.orchestrator:agent_orchestrator:146 - Latency: 1983ms
# 2026-04-22 21:42:15.139 | INFO     | src.agents.orchestrator:agent_orchestrator:147 - Total Tokens:250
# 2026-04-22 21:42:15.139 | INFO     | src.agents.orchestrator:agent_orchestrator:148 - Total Token Cost: $0.000040
# 2026-04-22 21:42:15.140 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
#
# ====================================================================================================
# 2026-04-22 21:42:16.056 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:42:16.057 | INFO     | src.agents.orchestrator:agent_orchestrator:145 - Not a SQL query
# 2026-04-22 21:42:16.058 | INFO     | src.agents.orchestrator:agent_orchestrator:146 - Latency: 916ms
# 2026-04-22 21:42:16.059 | INFO     | src.agents.orchestrator:agent_orchestrator:147 - Total Tokens:250
# 2026-04-22 21:42:16.060 | INFO     | src.agents.orchestrator:agent_orchestrator:148 - Total Token Cost: $0.000040
# 2026-04-22 21:42:16.061 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
#
# ====================================================================================================
# 2026-04-22 21:42:16.891 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:42:16.892 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:42:16.893 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:42:17.533 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:42:17.533 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:42:17.534 | INFO     | src.agents.orchestrator:agent_orchestrator:107 - SQL generator agent is called
# 2026-04-22 21:42:17.534 | WARNING  | src.agents.sql_generator:generate_sql:167 - No tables found for the given query
# 2026-04-22 21:42:17.536 | WARNING  | src.agents.orchestrator:agent_orchestrator:111 - SQL query is not generated.Please check you prompt or schema
# 2026-04-22 21:42:17.536 | INFO     | src.agents.orchestrator:agent_orchestrator:118 - SQL generator agent is completed
# 2026-04-22 21:42:17.537 | INFO     | src.agents.orchestrator:agent_orchestrator:121 - Generated SQL query:
# 2026-04-22 21:42:17.537 | INFO     | src.agents.orchestrator:agent_orchestrator:123 - User query: Drop all tables
# 2026-04-22 21:42:17.537 | INFO     | src.agents.orchestrator:agent_orchestrator:129 - Latency: 1476ms
# 2026-04-22 21:42:17.538 | INFO     | src.agents.orchestrator:agent_orchestrator:130 - Total Tokens: 248
# 2026-04-22 21:42:17.538 | INFO     | src.agents.orchestrator:agent_orchestrator:131 - Total Token Cost: $0.000039
# 2026-04-22 21:42:17.539 | INFO     | src.agents.orchestrator:agent_orchestrator:38 - Router intent agent is called
# ====================================================================================================
# 2026-04-22 21:42:18.384 | INFO     | src.agents.orchestrator:agent_orchestrator:46 - Router intent agent is completed
# 2026-04-22 21:42:18.385 | INFO     | src.agents.orchestrator:agent_orchestrator:50 - Checking SQL query ambiguity
# 2026-04-22 21:42:18.385 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:42:19.731 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:42:19.732 | WARNING  | src.agents.sql_generator:_check_ambiguity:441 - Query classified as AMBIGUOUS/INVALID
# 2026-04-22 21:42:19.734 | WARNING  | src.agents.orchestrator:agent_orchestrator:54 - Query is ambiguous, starting refinement
# 2026-04-22 21:42:19.735 | INFO     | src.agents.sql_generator:refine_query:475 - Refinement iteration 1
# 2026-04-22 21:43:08.843 | DEBUG    | src.agents.sql_generator:refine_query:498 - Refine user query
# 2026-04-22 21:43:08.843 | INFO     | src.agents.sql_generator:_check_ambiguity:408 - Starting ambiguity check
# 2026-04-22 21:43:09.798 | DEBUG    | src.agents.sql_generator:_check_ambiguity:427 - Ambiguity raw response
# 2026-04-22 21:43:09.799 | INFO     | src.agents.sql_generator:_check_ambiguity:437 - Query classified as CLEAR
# 2026-04-22 21:43:09.800 | INFO     | src.agents.sql_generator:refine_query:507 - Query refinement completed successfully
# 2026-04-22 21:43:09.800 | INFO     | src.agents.orchestrator:agent_orchestrator:62 - Refined user query
# 2026-04-22 21:43:09.801 | INFO     | src.agents.orchestrator:agent_orchestrator:63 - Refinement iterations: 1
# 2026-04-22 21:43:09.801 | INFO     | src.agents.orchestrator:agent_orchestrator:66 - SQL generator agent is called
# 2026-04-22 21:43:10.796 | INFO     | src.agents.orchestrator:agent_orchestrator:77 - SQL generator agent is completed
# 2026-04-22 21:43:10.797 | INFO     | src.agents.orchestrator:agent_orchestrator:80 - Generated SQL query: DELETE FROM patients;
# 2026-04-22 21:43:10.797 | INFO     | src.agents.orchestrator:agent_orchestrator:82 - User query: Refined Query: Delete all patient records from the database.
# 2026-04-22 21:43:10.798 | INFO     | src.agents.orchestrator:agent_orchestrator:88 - Latency: 53258ms
# 2026-04-22 21:43:10.799 | INFO     | src.agents.orchestrator:agent_orchestrator:89 - Total Tokens: 561
# 2026-04-22 21:43:10.800 | INFO     | src.agents.orchestrator:agent_orchestrator:90 - Total Token Cost: $0.000096
# ====================================================================================================
